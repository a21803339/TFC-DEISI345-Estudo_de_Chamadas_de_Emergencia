# %% [markdown]
# Começo do Código

# %%
# Data manipulation
import pandas as pd
import numpy as np

# Data visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Carregar o Dataset

# %%
#db = pd.read_csv('data/Dados_2022.csv', encoding='latin-1')
df = pd.read_excel('Data/Dados_mes_2022.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  7 non-null      object
#  1   Setembro    7 non-null      int64
#  2   Outubro     7 non-null      int64
#  3   Novembro    7 non-null      int64
#  4   Dezembro    7 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 408.0+ bytes

# %%
df.describe()
# Out:
#            Setembro       Outubro      Novembro      Dezembro
# count      7.000000      7.000000      7.000000      7.000000
# mean   17086.142857  18163.142857  17801.285714  18476.142857
# std     1903.503299   2132.960965   1883.006259   2953.229217
# min    15905.000000  16069.000000  15945.000000  12857.000000
# 25%    15969.000000  16679.500000  16601.000000  17218.500000
# 50%    16000.000000  16911.000000  16911.000000  19835.000000
# 75%    17912.500000  19513.500000  18920.000000  20517.500000
# max    19935.000000  21776.000000  20711.000000  21169.000000

# %%
df.head()
# Out:
#   Unnamed: 0  Setembro  Outubro  Novembro  Dezembro
# 0    Segunda     16000    21776     17667     17500
# 1      Terça     16017    16455     20173     16937
# 2     Quarta     15997    16069     20711     12857
# 3     Quinta     19808    16904     16911     20534
# 4      Sexta     19935    16911     16751     21169

# %%
df[['Unnamed: 0']].values
# Out:
# array([['Segunda'],
#        ['Terça'],
#        ['Quarta'],
#        ['Quinta'],
#        ['Sexta'],
#        ['Sábado'],
#        ['Domingo']], dtype=object)

# %%
ax = df.plot(alpha=0.8)
ax.set_xticks(range(len(df)))
ax.set_xticklabels(df['Unnamed: 0'])
plt.xlabel("Dias da Semana")
plt.ylabel("Número Chamadas")
plt.savefig('Results/chamadas_dia_mes.pdf')
